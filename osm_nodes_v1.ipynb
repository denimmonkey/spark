# %%
import findspark
findspark.init()
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
node_schema = StructType([StructField("id",LongType(),True),
StructField("version",IntegerType(),True),
StructField("timestamp",LongType(),True),
StructField("changeset",LongType(),True),
StructField("uid",IntegerType(),True),
StructField("user_sid",BinaryType(),True),
StructField("tags",ArrayType(StructType([StructField("key",StringType(),True),StructField("value",StringType(),True)]),True),True),
StructField("latitude",DoubleType(),True),
StructField("longitude",DoubleType(),True)])

# %%
node_df = spark.read.schema(node_schema).parquet("/Users/mayankbaid/Downloads/hungary_osm/20190430-hungary.osm.pbf.node.parquet")
node_df.createOrReplaceTempView("nodes")

# %%
node_df.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- version: integer (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- changeset: long (nullable = true)
#  |-- uid: integer (nullable = true)
#  |-- user_sid: binary (nullable = true)
#  |-- tags: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- key: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)

# %%
exploded_nodes = node_df.select("id",explode("tags").alias("exp_tags"))
exploded_nodes.show(truncate=False)
# Out:
# +-------+--------------------------+
# |id     |exp_tags                  |
# +-------+--------------------------+
# |277309 |[highway, traffic_signals]|
# |449380 |[name, Mörbisch am See]   |
# |449380 |[traffic_sign, city_limit]|
# |7916545|[created_by, JOSM]        |
# |7916549|[created_by, JOSM]        |
# |7916653|[created_by, JOSM]        |
# |7916662|[crossing, uncontrolled]  |
# |7916662|[crossing_ref, zebra]     |
# |7916662|[highway, crossing]       |
# |7916666|[created_by, JOSM]        |
# |7916715|[created_by, JOSM]        |
# |7916716|[created_by, JOSM]        |
# |7916717|[created_by, JOSM]        |
# |7918195|[created_by, JOSM]        |
# |7918201|[created_by, JOSM]        |
# |7918202|[created_by, JOSM]        |
# |7918208|[created_by, JOSM]        |
# |7918234|[created_by, JOSM]        |
# |7918240|[created_by, JOSM]        |
# |7918241|[created_by, JOSM]        |
# +-------+--------------------------+
# only showing top 20 rows

# %%
exploded_nodes.select("exp_tags.key").distinct().orderBy("key").show(exploded_nodes.count(),truncate=False)
# Out:
# +---------------------------------------------+
# |key                                          |
# +---------------------------------------------+
# |Csolnok                                      |
# |FIXME                                        |
# |GPS                                          |
# |HU:hu-go:milestone                           |
# |HU:hu-go:milestone_1                         |
# |HU:hu-go:road                                |
# |HU:hu-go:road_1                              |
# |ISO3166-1                                    |
# |ISO3166-2                                    |
# |Icn                                          |
# |Label                                        |
# |Leiras                                       |
# |Letrehozta                                   |
# |Letrehozva                                   |
# |MCC                                          |
# |MNC                                          |
# |Megjegyzes                                   |
# |Modositotta                                  |
# |Modositva                                    |
# |Operator                                     |
# |SIRUTA:code                                  |
# |ULPIA                                        |
# |[count]                                      |
# |abandoned                                    |
# |abandoned:aerialway                          |
# |abandoned:aeroway                            |
# |abandoned:amenity                            |
# |abandoned:atm                                |
# |abandoned:backrest                           |
# |abandoned:barrier                            |
# |abandoned:board_type                         |
# |abandoned:brand                              |
# |abandoned:building                           |
# |abandoned:craft                              |
# |abandoned:cuisine                            |
# |abandoned:entrance                           |
# |abandoned:highway                            |
# |abandoned:information                        |
# |abandoned:landuse                            |
# |abandoned:leisure                            |
# |abandoned:man_made                           |
# |abandoned:military                           |
# |abandoned:name                               |
# |abandoned:natural                            |
# |abandoned:opening_hours                      |
# |abandoned:operator                           |
# |abandoned:phone                              |
# |abandoned:power                              |
# |abandoned:public_transport                   |
# |abandoned:railway                            |
# |abandoned:railway:signal:catenary_mast       |
# |abandoned:railway:signal:direction           |
# |abandoned:railway:signal:main:form           |
# |abandoned:railway:signal:main:function       |
# |abandoned:railway:signal:position            |
# |abandoned:recycling_type                     |
# |abandoned:service:bicycle:repair             |
# |abandoned:service:bicycle:retail             |
# |abandoned:shelter_type                       |
# |abandoned:shop                               |
# |abandoned:start_date                         |
# |abandoned:tourism                            |
# |abandoned:tower:type                         |
# |abandoned:website                            |
# |abandoned:wheelchair                         |
# |abandoned_amenity                            |
# |abandoned_name                               |
# |abandoned_place                              |
# |abandoned_shop                               |
# |access                                       |
# |access:conditional                           |
# |access:description                           |
# |access:disabled                              |
# |access:hgv                                   |
# |access:lpg                                   |
# |accuracy                                     |
# |addr2:street                                 |
# |addr:GPS                                     |
# |addr:city                                    |
# |addr:city:en                                 |
# |addr:conscriptionnumber                      |
# |addr:country                                 |
# |addr:country_1                               |
# |addr:district                                |
# |addr:door                                    |
# |addr:flats                                   |
# |addr:floor                                   |
# |addr:full                                    |
# |addr:hamlet                                  |
# |addr:house                                   |
# |addr:housename                               |
# |addr:housenumber                             |
# |addr:housenumber_1                           |
# |addr:inclusion                               |
# |addr:interpolation                           |
# |addr:old_housenumber                         |
# |addr:orig_street                             |
# |addr:place                                   |
# |addr:place:hu                                |
# |addr:place:sl                                |
# |addr:postcode                                |
# |addr:province                                |
# |addr:region                                  |
# |addr:region:hu                               |
# |addr:staircase                               |
# |addr:state                                   |
# |addr:street                                  |
# |addr:street:hu                               |
# |addr:street:sk                               |
# |addr:street_1                                |
# |addr:streetnumber                            |
# |addr:subdistrict                             |
# |addr:suburb                                  |
# |addr:unit                                    |
# |admin_level                                  |
# |advertisement                                |
# |advertising                                  |
# |aerial                                       |
# |aerialway                                    |
# |aerialway:access                             |
# |aerialway:summer:access                      |
# |aeroway                                      |
# |age                                          |
# |age_group                                    |
# |agency                                       |
# |agrarian                                     |
# |air_conditioning                             |
# |airmark                                      |
# |alatt                                        |
# |alt_addr:housenumber                         |
# |alt_addr:street                              |
# |alt_name                                     |
# |alt_name2                                    |
# |alt_name:cs                                  |
# |alt_name:de                                  |
# |alt_name:en                                  |
# |alt_name:eo                                  |
# |alt_name:hu                                  |
# |alt_name:lfn                                 |
# |alt_name:ro                                  |
# |alt_name:ru                                  |
# |alt_name:sk                                  |
# |alt_name:sl                                  |
# |alt_name:uk                                  |
# |alt_name:vi                                  |
# |alt_name_1                                   |
# |alt_phone                                    |
# |amenity                                      |
# |amenity:disused                              |
# |amenity:removed                              |
# |amenity_1                                    |
# |amenity_2                                    |
# |amperage                                     |
# |animal                                       |
# |animal_boarding                              |
# |animal_shelter                               |
# |animal_training                              |
# |animal_trap:doors                            |
# |animal_trap:type                             |
# |animated                                     |
# |architect                                    |
# |area                                         |
# |areasize:sqm                                 |
# |artisan                                      |
# |artist:wikidata                              |
# |artist:wikipedia                             |
# |artist_name                                  |
# |artwork                                      |
# |artwork:type                                 |
# |artwork_subject                              |
# |artwork_type                                 |
# |astronomy                                    |
# |at_bev:addr_date                             |
# |athletics:hammer_throw                       |
# |atm                                          |
# |atm:bitcoin                                  |
# |attraction                                   |
# |authentication:membership_card               |
# |authentication:nfc                           |
# |authentication:none                          |
# |author                                       |
# |automated                                    |
# |automatic_door                               |
# |award:hotelstars                             |
# |baby                                         |
# |backcountry                                  |
# |background_music                             |
# |backrest                                     |
# |bar                                          |
# |barometer                                    |
# |barr                                         |
# |barrier                                      |
# |bath:open_air                                |
# |bath:type                                    |
# |beacon                                       |
# |beacon:code                                  |
# |beacon:colour                                |
# |beacon:frequency                             |
# |beacon:type                                  |
# |beauty                                       |
# |beauty_1                                     |
# |beauty_2                                     |
# |beds                                         |
# |beer_garden                                  |
# |bench                                        |
# |bic                                          |
# |bicycle                                      |
# |bicycle:conditional                          |
# |bicycle:repair                               |
# |bicycle:source                               |
# |bicycle_parking                              |
# |bicycle_rental                               |
# |biergarten                                   |
# |bijou                                        |
# |bike                                         |
# |bike_ride                                    |
# |billiards:carom                              |
# |billiards:pool                               |
# |billiards:snooker                            |
# |bin                                          |
# |bing_sat                                     |
# |birds_nest                                   |
# |blind                                        |
# |blind:description:en                         |
# |blind:description:hu                         |
# |block                                        |
# |blood:plasma                                 |
# |board_type                                   |
# |bollard                                      |
# |bolt                                         |
# |bonnet:colour                                |
# |books                                        |
# |books:language:eo                            |
# |booth                                        |
# |bottle                                       |
# |boundary                                     |
# |braille                                      |
# |branch                                       |
# |branch:type                                  |
# |brand                                        |
# |brand:wikidata                               |
# |brand:wikipedia                              |
# |breakfast                                    |
# |breast                                       |
# |brewery                                      |
# |bridge                                       |
# |bridge:support                               |
# |brushless                                    |
# |bucker                                       |
# |building                                     |
# |building:architecture                        |
# |building:colour                              |
# |building:disused                             |
# |building:levels                              |
# |building:levels:aboveground                  |
# |building:levels:underground                  |
# |building:material                            |
# |building:part                                |
# |building:use                                 |
# |building_type                                |
# |bulk_purchase                                |
# |bunker_type                                  |
# |buried:wikidata                              |
# |buried:wikipedia                             |
# |bus                                          |
# |bus_bay                                      |
# |bus_lines                                    |
# |bus_routes                                   |
# |bus_stop:category                            |
# |busway:right                                 |
# |butcher                                      |
# |button_operated                              |
# |cables                                       |
# |cafe                                         |
# |calibration_point                            |
# |callsign                                     |
# |camera:angle                                 |
# |camera:count                                 |
# |camera:direction                             |
# |camera:make                                  |
# |camera:model                                 |
# |camera:mount                                 |
# |camera:type                                  |
# |camp_site                                    |
# |canoe_rental                                 |
# |cap:colour                                   |
# |capacity                                     |
# |capacity:beds                                |
# |capacity:bus                                 |
# |capacity:description                         |
# |capacity:disabled                            |
# |capacity:hgv                                 |
# |capacity:parent                              |
# |capacity:wheelchair                          |
# |capacity:women                               |
# |capital                                      |
# |capital_ISO3166-1                            |
# |capital_city                                 |
# |car                                          |
# |car_service                                  |
# |caravans                                     |
# |cargo                                        |
# |carpenter                                    |
# |cash                                         |
# |cash_in                                      |
# |castle_type                                  |
# |cat                                          |
# |cave:access                                  |
# |cave:ref                                     |
# |cave:type                                    |
# |cellar:type                                  |
# |cellar:use                                   |
# |cellid                                       |
# |cemetery                                     |
# |charge                                       |
# |charging_station:output                      |
# |charging_station:plug                        |
# |check_date                                   |
# |check_date:opening_hours                     |
# |checkpoint                                   |
# |checkpoint:course                            |
# |checkpoint:hiking                            |
# |checkpoint:name                              |
# |checkpoint:type                              |
# |checkpoint_type                              |
# |child                                        |
# |child_area                                   |
# |chimney:shape                                |
# |chip_scanner                                 |
# |church_ale                                   |
# |cid                                          |
# |cinema:3D                                    |
# |circumference                                |
# |city_id                                      |
# |city_limit                                   |
# |city_type                                    |
# |climbing:boulder                             |
# |climbing:rock                                |
# |closed                                       |
# |closest_town                                 |
# |clothes                                      |
# |clothes:children                             |
# |clothes:denim                                |
# |clothes:men                                  |
# |clothes:sports                               |
# |clothes:underwear                            |
# |clothes:wedding                              |
# |clothes:women                                |
# |club                                         |
# |cocktails                                    |
# |code                                         |
# |codul_entității_muzeale                      |
# |coffee                                       |
# |collection_times                             |
# |collection_times:signed                      |
# |collector                                    |
# |colour                                       |
# |comment                                      |
# |communication                                |
# |communication:antenna                        |
# |communication:gsm                            |
# |communication:gsm-r                          |
# |communication:lte                            |
# |communication:microwave                      |
# |communication:microwawe                      |
# |communication:mobile                         |
# |communication:mobile_phone                   |
# |communication:mobile_phone_1                 |
# |communication:radio                          |
# |communication:television                     |
# |communication:umts                           |
# |communication:wifi                           |
# |communication:wlan                           |
# |communications_transponder:frequency         |
# |communications_transponder:modulation        |
# |communications_transponder:power             |
# |community_centre                             |
# |community_centre:for                         |
# |compressed_air                               |
# |compressed_air:fee                           |
# |computer:parts                               |
# |computer:repair                              |
# |computer:sales                               |
# |computer:type                                |
# |construction                                 |
# |construction:amenity                         |
# |construction:man_made                        |
# |construction:railway                         |
# |construction:railway:local_operated          |
# |construction:railway:switch:electric         |
# |construction:shop                            |
# |construction_date                            |
# |contact:addr:full                            |
# |contact:email                                |
# |contact:email_1                              |
# |contact:facebook                             |
# |contact:fax                                  |
# |contact:fax_1                                |
# |contact:foursquare                           |
# |contact:google_plus                          |
# |contact:instagram                            |
# |contact:linkedin                             |
# |contact:messenger                            |
# |contact:mobile                               |
# |contact:name                                 |
# |contact:phone                                |
# |contact:phone_1                              |
# |contact:phone_2                              |
# |contact:phone_3                              |
# |contact:pinterest                            |
# |contact:skype                                |
# |contact:twitter                              |
# |contact:webcam                               |
# |contact:website                              |
# |contact:website:en                           |
# |contact:website_1                            |
# |contact:website_2                            |
# |contact:website_3                            |
# |contact:youtube                              |
# |content                                      |
# |control                                      |
# |converted_by                                 |
# |cooking                                      |
# |count                                        |
# |country                                      |
# |country_code_fips                            |
# |country_code_iso3166_1_alpha_2               |
# |couplings                                    |
# |couplings:diameters                          |
# |couplings:type                               |
# |course                                       |
# |cover                                        |
# |covered                                      |
# |craft                                        |
# |craft_1                                      |
# |crane:maxload                                |
# |crane:maxradius                              |
# |crane:operator                               |
# |crane:ship:maxdraft                          |
# |crane:ship:maxlength                         |
# |crane:type                                   |
# |created                                      |
# |created_by                                   |
# |crop                                         |
# |crossing                                     |
# |crossing:activation                          |
# |crossing:barrier                             |
# |crossing:bell                                |
# |crossing:island                              |
# |crossing:light                               |
# |crossing:lights                              |
# |crossing:saltire                             |
# |crossing_1                                   |
# |crossing_2                                   |
# |crossing_ref                                 |
# |cuisine                                      |
# |cuisine_1                                    |
# |currency                                     |
# |currency:BTC                                 |
# |currency:CHF                                 |
# |currency:EUR                                 |
# |currency:GBP                                 |
# |currency:HUF                                 |
# |currency:USD                                 |
# |currency:XBT                                 |
# |currency:huf                                 |
# |currency:others                              |
# |cycleway                                     |
# |dance:style                                  |
# |dance:teaching                               |
# |date                                         |
# |deduplicated                                 |
# |defibrillator:location                       |
# |delivery                                     |
# |demolished                                   |
# |demolished:amenity                           |
# |demolished:building                          |
# |demolished:chimney                           |
# |demolished:man_made                          |
# |demolished:museum                            |
# |demolished:natural                           |
# |demolished:shop                              |
# |demolished:tower                             |
# |denomination                                 |
# |denomination:1300-1600                       |
# |denotation                                   |
# |departures_board                             |
# |deposit                                      |
# |depth                                        |
# |depth:docks                                  |
# |depth:entry                                  |
# |des                                          |
# |descr                                        |
# |description                                  |
# |description:1                                |
# |description:2                                |
# |description:2016                             |
# |description:3                                |
# |description:de                               |
# |description:en                               |
# |description:hr                               |
# |description:hu                               |
# |description:ro                               |
# |description:ru                               |
# |description:sr                               |
# |design                                       |
# |designation                                  |
# |destination                                  |
# |destination:ref                              |
# |destroyed:historic                           |
# |destroyed:tourism                            |
# |devices                                      |
# |diameter                                     |
# |diameter_crown                               |
# |diaper                                       |
# |diet:gluten_free                             |
# |diet:halal                                   |
# |diet:kosher                                  |
# |diet:lactose_free                            |
# |diet:no_lacto                                |
# |diet:no_sugar                                |
# |diet:raw                                     |
# |diet:sugar_free                              |
# |diet:vegan                                   |
# |diet:vegetarian                              |
# |dinghy_rental                                |
# |diplomatic                                   |
# |diplomatic:sending_country                   |
# |dir                                          |
# |direction                                    |
# |disabled_spaces                              |
# |dispensing                                   |
# |display                                      |
# |display:analog                               |
# |display:digital                              |
# |distance                                     |
# |distillery                                   |
# |disused                                      |
# |disused:addr:housenumber                     |
# |disused:addr:postcode                        |
# |disused:addr:street                          |
# |disused:aeroway                              |
# |disused:amenity                              |
# |disused:atm                                  |
# |disused:barrier                              |
# |disused:communication:mobile_phone           |
# |disused:communication:wlan                   |
# |disused:contact:phone                        |
# |disused:contact:website                      |
# |disused:craft                                |
# |disused:cuisine                              |
# |disused:ford                                 |
# |disused:highway                              |
# |disused:information                          |
# |disused:internet_access:ssid                 |
# |disused:leisure                              |
# |disused:man_made                             |
# |disused:name                                 |
# |disused:office                               |
# |disused:opening_hours                        |
# |disused:phone                                |
# |disused:place                                |
# |disused:postal_code                          |
# |disused:power                                |
# |disused:public_transport                     |
# |disused:railway                              |
# |disused:shop                                 |
# |disused:surface                              |
# |disused:tourism                              |
# |disused:website                              |
# |disused:wheelchair                           |
# |dog                                          |
# |dog:description                              |
# |dog:maxweight                                |
# |dog:opening_hours                            |
# |door                                         |
# |drillmachine:rental                          |
# |drink                                        |
# |drink:beer                                   |
# |drink:wine                                   |
# |drinkable                                    |
# |drinking_water                               |
# |drinking_water:legal                         |
# |drinking_water:seasonal                      |
# |drinking_water:source                        |
# |drive_in                                     |
# |drive_through                                |
# |ele                                          |
# |ele:msl                                      |
# |ele:relative                                 |
# |ele:source                                   |
# |electrified                                  |
# |electronics                                  |
# |electronics_repair                           |
# |elevation                                    |
# |elevator                                     |
# |email                                        |
# |email:2                                      |
# |email:alt                                    |
# |emergency                                    |
# |employment_agency:type                       |
# |enb                                          |
# |end_date                                     |
# |enforcement                                  |
# |engraving                                    |
# |entrance                                     |
# |entrance_1                                   |
# |entry                                        |
# |esperanto                                    |
# |esr:code                                     |
# |esr:user                                     |
# |est_height                                   |
# |est_width                                    |
# |ethanol                                      |
# |ethnicity                                    |
# |examine                                      |
# |exhibit                                      |
# |exit                                         |
# |exit_to                                      |
# |facebook                                     |
# |facebook:hu                                  |
# |faces                                        |
# |fare_zone                                    |
# |farm                                         |
# |fast_food                                    |
# |fax                                          |
# |fee                                          |
# |fee:price                                    |
# |feeding:fodder                               |
# |feeding:for                                  |
# |feeding:type                                 |
# |female                                       |
# |fence_type                                   |
# |ferry                                        |
# |fire_hydrant:accessibility                   |
# |fire_hydrant:count                           |
# |fire_hydrant:coupling_type                   |
# |fire_hydrant:couplings                       |
# |fire_hydrant:diameter                        |
# |fire_hydrant:flow_capacity                   |
# |fire_hydrant:opening                         |
# |fire_hydrant:opening_direction               |
# |fire_hydrant:position                        |
# |fire_hydrant:pressure                        |
# |fire_hydrant:signage                         |
# |fire_hydrant:type                            |
# |fireplace                                    |
# |fishing                                      |
# |fitness_station                              |
# |fixme                                        |
# |fixme:tower:construction                     |
# |fixme_1                                      |
# |flag:type                                    |
# |flashing_lights                              |
# |flickr                                       |
# |floating                                     |
# |floor                                        |
# |flow_control                                 |
# |flow_rate                                    |
# |fm_radio                                     |
# |food                                         |
# |foot                                         |
# |foot:conditional                             |
# |footway                                      |
# |ford                                         |
# |format                                       |
# |format:top                                   |
# |fortification                                |
# |fortification_type                           |
# |fountain                                     |
# |free_flying:official                         |
# |free_flying:paragliding                      |
# |free_flying:site                             |
# |free_refill                                  |
# |free_refill_note                             |
# |frequency                                    |
# |frequency:LHBS                               |
# |from                                         |
# |fruit                                        |
# |fuel                                         |
# |fuel:100LL                                   |
# |fuel:1_25                                    |
# |fuel:1_50                                    |
# |fuel:95                                      |
# |fuel:GTL_diesel                              |
# |fuel:HGV_diesel                              |
# |fuel:biodiesel                               |
# |fuel:biogas                                  |
# |fuel:cng                                     |
# |fuel:diesel                                  |
# |fuel:e10                                     |
# |fuel:e85                                     |
# |fuel:electricity                             |
# |fuel:ethanol                                 |
# |fuel:gasoline                                |
# |fuel:lpg                                     |
# |fuel:octane_100                              |
# |fuel:octane_80                               |
# |fuel:octane_91                               |
# |fuel:octane_92                               |
# |fuel:octane_95                               |
# |fuel:octane_98                               |
# |fuel:oil                                     |
# |fuel:propane                                 |
# |full_name                                    |
# |function                                     |
# |functional                                   |
# |furniture                                    |
# |gambling                                     |
# |garden:style                                 |
# |garden:type                                  |
# |gate                                         |
# |gate:type                                    |
# |gay                                          |
# |gender                                       |
# |generator:method                             |
# |generator:model                              |
# |generator:output:electricity                 |
# |generator:output:heat                        |
# |generator:output:hot_water                   |
# |generator:place                              |
# |generator:source                             |
# |generator:type                               |
# |genus                                        |
# |genus:de                                     |
# |genus:en                                     |
# |genus:hu                                     |
# |geocaching                                   |
# |geological                                   |
# |geonames:id                                  |
# |golf:course                                  |
# |goods                                        |
# |government                                   |
# |group_only                                   |
# |gsm:BCCH                                     |
# |gsm:BSIC                                     |
# |gsm:LAC                                      |
# |gsm:cellid                                   |
# |gsm:direction                                |
# |gun_emplacement_type                         |
# |guyed                                        |
# |hackerspace                                  |
# |hairdye                                      |
# |halt                                         |
# |handrail:left                                |
# |handrail:right                               |
# |happy_hours                                  |
# |happy_hours:description                      |
# |happy_hours:food                             |
# |harbour                                      |
# |hazard                                       |
# |hazard_prone                                 |
# |hdop                                         |
# |headframe                                    |
# |health_facility                              |
# |health_facility:type                         |
# |health_person                                |
# |health_specialty:obstetrics                  |
# |healthcare                                   |
# |healthcare:speciality                        |
# |heating                                      |
# |height                                       |
# |height:hub                                   |
# |heritage                                     |
# |heritage:operator                            |
# |heritage:website                             |
# |hgv                                          |
# |hidden                                       |
# |hide                                         |
# |high                                         |
# |high_ropes_course                            |
# |highchair                                    |
# |highway                                      |
# |highway_1                                    |
# |highway_2                                    |
# |hiking                                       |
# |historic                                     |
# |historic:civilisation                        |
# |historic:civilization                        |
# |historic:landuse                             |
# |historic:period                              |
# |historical                                   |
# |history                                      |
# |hoops                                        |
# |horse                                        |
# |hot_water                                    |
# |hotel                                        |
# |hours                                        |
# |hov                                          |
# |hrsz                                         |
# |hunting                                      |
# |hunting_stand                                |
# |hygrometer                                   |
# |iata                                         |
# |icao                                         |
# |ice_cream                                    |
# |ice_cream:type                               |
# |id                                           |
# |identity                                     |
# |illegal                                      |
# |illegal:amenity                              |
# |image                                        |
# |img                                          |
# |import                                       |
# |import_ref                                   |
# |importance                                   |
# |in_in:city                                   |
# |incline                                      |
# |indoor                                       |
# |industrial                                   |
# |infant_bed                                   |
# |information                                  |
# |information:map                              |
# |inscription                                  |
# |inscription:1                                |
# |inscription:2                                |
# |inscription:3                                |
# |inscription:de                               |
# |inscription:eo                               |
# |inscription:hu                               |
# |inscription:n                                |
# |inscription:s                                |
# |inscription:url                              |
# |instagram                                    |
# |int_name                                     |
# |interaction                                  |
# |intermittent                                 |
# |internet_access                              |
# |internet_access:access                       |
# |internet_access:description                  |
# |internet_access:fee                          |
# |internet_access:ssid                         |
# |internet_access:ssid_1                       |
# |internet_access:ssid_2                       |
# |internet_access:type                         |
# |iof                                          |
# |is_in                                        |
# |is_in:                                       |
# |is_in:city                                   |
# |is_in:continent                              |
# |is_in:country                                |
# |is_in:country_code                           |
# |is_in:county                                 |
# |is_in:iso_3166_2                             |
# |is_in:municipality                           |
# |is_in:subregion                              |
# |is_in:suburb                                 |
# |is_in:town                                   |
# |is_in:village                                |
# |is_in:zoo                                    |
# |isced:level                                  |
# |it:type                                      |
# |jel                                          |
# |josm_bing_offset                             |
# |junction                                     |
# |kerb                                         |
# |kerb:height                                  |
# |kids_area                                    |
# |kindergarten                                 |
# |koatuu                                       |
# |ksh_ref                                      |
# |lac                                          |
# |lac:stats                                    |
# |ladder                                       |
# |lamp:count                                   |
# |lamp:light:hu                                |
# |lamp:type                                    |
# |lamp_model                                   |
# |lamp_mount                                   |
# |lamp_operator                                |
# |lamp_post_material                           |
# |lamp_type                                    |
# |land_property                                |
# |landmark                                     |
# |landuse                                      |
# |lanes                                        |
# |lanes:forward                                |
# |lastcheck                                    |
# |lawyer                                       |
# |layer                                        |
# |lcn                                          |
# |leaf_cycle                                   |
# |leaf_type                                    |
# |legal                                        |
# |leisure                                      |
# |length                                       |
# |letter_box:type                              |
# |level                                        |
# |level_crossing                               |
# |level_crossing:light                         |
# |level_crossing:traffic_signals               |
# |levels                                       |
# |lgbtq                                        |
# |liaison                                      |
# |library                                      |
# |license_classes                              |
# |lift_gate                                    |
# |lift_gate:type                               |
# |light                                        |
# |light:lit                                    |
# |light:shape                                  |
# |light:tilt                                   |
# |light_rail                                   |
# |light_source                                 |
# |line                                         |
# |lines                                        |
# |lines_1                                      |
# |link                                         |
# |lit                                          |
# |loc_name                                     |
# |loc_name:de                                  |
# |loc_name:en                                  |
# |local_name                                   |
# |local_ref                                    |
# |location                                     |
# |location:communication:tower                 |
# |location:mobilphone:tower                    |
# |location:transition                          |
# |lock:count                                   |
# |lockabel                                     |
# |lockable                                     |
# |locomotive:type                              |
# |lottery                                      |
# |loyalty_card                                 |
# |lte:LAC                                      |
# |lte:PCI                                      |
# |lte:PSC                                      |
# |lte:RNC                                      |
# |lte:band                                     |
# |lte:cellid                                   |
# |lte:direction                                |
# |lte:eNB                                      |
# |luminous                                     |
# |lunch                                        |
# |lunch:buffet                                 |
# |lunch:buffet:cost                            |
# |lunch:buffet:url                             |
# |lunch:menu                                   |
# |lunch:menu:choices                           |
# |lunch:menu:cost                              |
# |lunch:menu:course:dessert                    |
# |lunch:menu:course:drink                      |
# |lunch:menu:course:main                       |
# |lunch:menu:course:sandwich                   |
# |lunch:menu:course:soup                       |
# |lunch:menu:cuisine                           |
# |lunch:menu:daily_special                     |
# |lunch:menu:delivery                          |
# |lunch:menu:delivery:fee                      |
# |lunch:menu:delivery:service_times            |
# |lunch:menu:dessert                           |
# |lunch:menu:email                             |
# |lunch:menu:main                              |
# |lunch:menu:price                             |
# |lunch:menu:publish_time                      |
# |lunch:menu:subscription                      |
# |lunch:menu:subscription:description          |
# |lunch:menu:takeaway                          |
# |lunch:menu:url                               |
# |male                                         |
# |man                                          |
# |man_made                                     |
# |manhole                                      |
# |manometer                                    |
# |manufacturer                                 |
# |manufacturer:type                            |
# |map                                          |
# |map_size                                     |
# |map_type                                     |
# |mapillary                                    |
# |marked_trail                                 |
# |marked_trail_edu                             |
# |marker                                       |
# |massage                                      |
# |material                                     |
# |material:hu                                  |
# |mattress                                     |
# |max_age                                      |
# |maxheight                                    |
# |maxspeed                                     |
# |maxspeed:bus                                 |
# |maxspeed:hgv                                 |
# |maxstay                                      |
# |maxweight                                    |
# |maxweight:conditional                        |
# |maxwidth                                     |
# |mcc                                          |
# |measured                                     |
# |measurement                                  |
# |memorial                                     |
# |memorial:addr                                |
# |memorial:name                                |
# |memorial:subject                             |
# |memorial:text                                |
# |memorial:type                                |
# |memorial_1                                   |
# |men                                          |
# ...
# |source:postal_code:date                      |
# |source:ref                                   |
# |source:seats                                 |
# |source:shop                                  |
# |source:sqkm                                  |
# |source:tesco.hu:date                         |
# |source:url                                   |
# |source:wheelchair                            |
# |source_1                                     |
# |source_date                                  |
# |source_ref                                   |
# |spa                                          |
# |species                                      |
# |species:de                                   |
# |species:eg                                   |
# |species:en                                   |
# |species:hu                                   |
# |species:nl                                   |
# |species:sk                                   |
# |speed                                        |
# |sport                                        |
# |sport:pinball                                |
# |sport:table_soccer                           |
# |sport_1                                      |
# |sport_2                                      |
# |sport_3                                      |
# |sqkm                                         |
# |staff                                        |
# |stairs                                       |
# |stamps                                       |
# |stars                                        |
# |start_date                                   |
# |station                                      |
# |statue                                       |
# |statue:animal                                |
# |status                                       |
# |step_count                                   |
# |stile                                        |
# |stop                                         |
# |stopColorType                                |
# |stop_date                                    |
# |strapline                                    |
# |strazakosm:send_date                         |
# |strazakosm:sender_id                         |
# |street:hu                                    |
# |street_cabinet                               |
# |strike_tone                                  |
# |structure                                    |
# |studio                                       |
# |subject:wikidata                             |
# |subject:wikipedia                            |
# |substance                                    |
# |substation                                   |
# |subway                                       |
# |summit:cross                                 |
# |supervised                                   |
# |support                                      |
# |surface                                      |
# |surveillance                                 |
# |surveillance:type                            |
# |surveillance:zone                            |
# |survey                                       |
# |survey:date                                  |
# |survey_date                                  |
# |swimming_pool                                |
# |swing_gate                                   |
# |swing_gate:type                              |
# |switch                                       |
# |symbol:hu                                    |
# |table                                        |
# |table_tennis:net                             |
# |table_tennis:tables                          |
# |tables                                       |
# |tac                                          |
# |tactile_paving                               |
# |tactile_writing:braille:lg                   |
# |takeaway                                     |
# |target                                       |
# |taxi                                         |
# |taxon                                        |
# |taxon:en                                     |
# |taxon:genus                                  |
# |taxon:hu                                     |
# |taxon:species                                |
# |telephone_area_code                          |
# |telescope:diameter                           |
# |telescope:type                               |
# |temperature                                  |
# |tents                                        |
# |theatre:genre                                |
# |theatre:type                                 |
# |theme                                        |
# |thermometer                                  |
# |tilos                                        |
# |to                                           |
# |tobacco                                      |
# |todo                                         |
# |toilets                                      |
# |toilets:access                               |
# |toilets:disposal                             |
# |toilets:hot_water                            |
# |toilets:position                             |
# |toilets:wheelchair                           |
# |toll                                         |
# |tomb                                         |
# |top_up:posta_csekk                           |
# |topic                                        |
# |tourism                                      |
# |tourism_1                                    |
# |tourism_survey                               |
# |tower                                        |
# |tower:construction                           |
# |tower:material                               |
# |tower:structure                              |
# |tower:type                                   |
# |tower:type_1                                 |
# |townhall:type                                |
# |toys:model_railway                           |
# |traces                                       |
# |trade                                        |
# |traffic_calming                              |
# |traffic_sign                                 |
# |traffic_sign:2                               |
# |traffic_sign:backward                        |
# |traffic_sign:direction                       |
# |traffic_sign:forward                         |
# |traffic_signals                              |
# |traffic_signals:direction                    |
# |traffic_signals:sound                        |
# |traffic_signals:vibration                    |
# |train                                        |
# |training                                     |
# |tram                                         |
# |transformer                                  |
# |transformer:ref                              |
# |transport                                    |
# |tree:diameter                                |
# |trolleybus                                   |
# |truck                                        |
# |tuhu                                         |
# |tunnel                                       |
# |turn:lanes                                   |
# |turn:lanes:backward                          |
# |tv                                           |
# |tv:seasonal                                  |
# |twitter                                      |
# |type                                         |
# |uic_name                                     |
# |uic_ref                                      |
# |umtd:RNC                                     |
# |umts                                         |
# |umts:LAC                                     |
# |umts:PSC                                     |
# |umts:RNC                                     |
# |umts:cellid                                  |
# |umts:direction                               |
# |umts:psc                                     |
# |unisex                                       |
# |url                                          |
# |url:1                                        |
# |url:11161                                    |
# |url:11168                                    |
# |url:1961                                     |
# |url:1967                                     |
# |url:2                                        |
# |url:2017                                     |
# |url:3                                        |
# |url:9x                                       |
# |url:Csepel                                   |
# |url:Nagymaros                                |
# |url:archeodatabase                           |
# |url:bacskiskun                               |
# |url:blog                                     |
# |url:booking                                  |
# |url:borzsony938m.blog                        |
# |url:bushcraft                                |
# |url:ceginfo                                  |
# |url:darksky                                  |
# |url:egkep                                    |
# |url:epiteszforum                             |
# |url:geocaching                               |
# |url:geocaching.hu                            |
# |url:geopark                                  |
# |url:gmap                                     |
# |url:hnp                                      |
# |url:kesportal                                |
# |url:kisvasut                                 |
# |url:kozterkep                                |
# |url:kozterkep.hu                             |
# |url:kulcsoshaz                               |
# |url:lexikon.katolikus                        |
# |url:limes_pannonia                           |
# |url:marianosztrakegyhely                     |
# |url:mek.oszk                                 |
# |url:menetrend                                |
# |url:menetrend2                               |
# |url:metrodom                                 |
# |url:miserend                                 |
# |url:miserend.hu                              |
# |url:mno                                      |
# |url:mtak                                     |
# |url:muemlekem                                |
# |url:mult                                     |
# |url:museum                                   |
# |url:mvte                                     |
# |url:nyitva                                   |
# |url:onkormanyzat.net                         |
# |url:opten                                    |
# |url:oszk                                     |
# |url:pilisrejtely                             |
# |url:ronaorzo                                 |
# |url:sulinet                                  |
# |url:szallas                                  |
# |url:tuhu                                     |
# |url:tuosm                                    |
# |url:turistautak                              |
# |url:tájegységek                              |
# |url:vadonszava                               |
# |url:varak                                    |
# |url:velenceito                               |
# |url:webetyek                                 |
# |url:wikimapia                                |
# |url:zmne                                     |
# |url_1                                        |
# |usage                                        |
# |user_defined_other                           |
# |utility                                      |
# |valve                                        |
# |valves                                       |
# |vehicle                                      |
# |vehicle:lpg                                  |
# |vending                                      |
# |vending_machine                              |
# |verified                                     |
# |verify                                       |
# |via_ferrata_scale                            |
# |video                                        |
# |viewpoint                                    |
# |visibility                                   |
# |voltage                                      |
# |voltage-high                                 |
# |voltage-low                                  |
# |voltage:primary                              |
# |voltage:secondary                            |
# |was:amenity                                  |
# |was:emergency                                |
# |was:shop                                     |
# |waste                                        |
# |waste_1                                      |
# |waste_basket                                 |
# |waste_type                                   |
# |water                                        |
# |water_characteristic                         |
# |water_slide                                  |
# |water_source                                 |
# |water_tank:volume                            |
# |water_volume                                 |
# |water_well                                   |
# |waterway                                     |
# |waterway:sign                                |
# |wayside_cross                                |
# |weather:anemometer                           |
# |weather:barometer                            |
# |weather:ceilometer                           |
# |weather:forward_scatter_sensor               |
# |weather:grass_minimum_thermometer            |
# |weather:humidity_sensor                      |
# |weather:ombrometer                           |
# |weather:precipitation_indicator              |
# |weather:psychrometer                         |
# |weather:pyranometer                          |
# |weather:radar                                |
# |weather:soil_thermometer                     |
# |weather:sunshine_recorder                    |
# |weather:thermometer                          |
# |web                                          |
# |webshop                                      |
# |website                                      |
# |website2                                     |
# |website:2                                    |
# |website:de                                   |
# |website:en                                   |
# |website:hu                                   |
# |website:tajertek                             |
# |website_1                                    |
# |website_2                                    |
# |website_3                                    |
# |website_old                                  |
# |weight                                       |
# |wellness                                     |
# |wetap:status                                 |
# |wetland                                      |
# |wheelchair                                   |
# |wheelchair:description                       |
# |wheelchair:description:de                    |
# |wheelchair:description:en                    |
# |wheelchair:description:hu                    |
# |wheelchair:entrance_width                    |
# |wheelchair:source                            |
# |wheelchair:step_height                       |
# |whitewater                                   |
# |whitewater:name                              |
# |wholesale                                    |
# |width                                        |
# |wifi                                         |
# |wikidata                                     |
# |wikimedia                                    |
# |wikimedia_commons                            |
# |wikipedia                                    |
# |wikipedia:de                                 |
# |wikipedia:en                                 |
# |wikipedia:hu                                 |
# |wikipedia:pl                                 |
# |wikipedia:ru                                 |
# |wikipedia:sl                                 |
# |windmill:type                                |
# |windmill:vanes                               |
# |window                                       |
# |wires                                        |
# |workshop                                     |
# |wpt_description                              |
# |wpt_symbol                                   |
# |xmas:feature                                 |
# |year                                         |
# |year_of_construction                         |
# |youtube                                      |
# |zebra                                        |
# |zone                                         |
# |zone:maxspeed                                |
# |zoo                                          |
# |Állapot                                      |
# |ÉMKK_name                                    |
# +---------------------------------------------+

# %%
atms = exploded_nodes.filter("exp_tags.key == 'atm'")

# %%
atms.count()
# Out:
# 857

# %%
utilit = exploded_nodes.filter("exp_tags.key == 'utility'")

# %%
utilit.select("*").show(truncate=False)
# Out:
# +---------+---------------------+
# |id       |exp_tags             |
# +---------+---------------------+
# |874150243|[utility, wastewater]|
# +---------+---------------------+

# %%
bars = exploded_nodes.filter("exp_tags.key == 'bar'")
bars.count()
# Out:
# 1

# %%
exploded_nodes.select("exp_tags.key").groupBy("key").count().orderBy("count").show(exploded_nodes.count(),truncate=False)
# Out:
# +---------------------------------------------+------+
# |key                                          |count |
# +---------------------------------------------+------+
# |url:miserend.hu                              |1     |
# |old:addr:housenumber                         |1     |
# |men                                          |1     |
# |name:haw                                     |1     |
# |name:mt                                      |1     |
# |computer:parts                               |1     |
# |name:gn                                      |1     |
# |source:emergency                             |1     |
# |official_name:fr                             |1     |
# |lunch:menu:subscription:description          |1     |
# |name:alt                                     |1     |
# |fuel:octane_92                               |1     |
# |inscription:s                                |1     |
# |sac_scale                                    |1     |
# |crossing:activation                          |1     |
# |name:dv                                      |1     |
# |motorcycle:conditional                       |1     |
# |drillmachine:rental                          |1     |
# |url:mult                                     |1     |
# |name:tet                                     |1     |
# |addr:street:sk                               |1     |
# |cash                                         |1     |
# |abandoned:railway:signal:main:function       |1     |
# |service:vehicle:glass                        |1     |
# |official_name:en                             |1     |
# |name:lo                                      |1     |
# |name:or                                      |1     |
# |contact:website_3                            |1     |
# |post_box                                     |1     |
# |lunch:menu:delivery:service_times            |1     |
# |psc:stats                                    |1     |
# |HU:hu-go:road_1                              |1     |
# |bar                                          |1     |
# |functional                                   |1     |
# |name:ss                                      |1     |
# |sport_3                                      |1     |
# |source:location                              |1     |
# |name:tpi                                     |1     |
# |seamark:notice:5:impact                      |1     |
# |musical_instrument:rental                    |1     |
# |official_name:ku                             |1     |
# |agrarian                                     |1     |
# |computer:sales                               |1     |
# |operator_1                                   |1     |
# |phone:hairdresser                            |1     |
# |theme                                        |1     |
# |railway_1                                    |1     |
# |heating                                      |1     |
# |ele:msl                                      |1     |
# |payment:forint                               |1     |
# |cave:access                                  |1     |
# |electronics_repair                           |1     |
# |alt_name:sk                                  |1     |
# |service:vehicle:exhausts                     |1     |
# |proposed:leisure                             |1     |
# |source:shop                                  |1     |
# |hackerspace                                  |1     |
# |recording                                    |1     |
# |tuhu                                         |1     |
# |lunch:menu:course:sandwich                   |1     |
# |official_name:lb                             |1     |
# |alt_name:sl                                  |1     |
# |wheelchair:source                            |1     |
# |robot:type                                   |1     |
# |name:etymology:wikidata                      |1     |
# |child_area                                   |1     |
# |name:zu                                      |1     |
# |raised                                       |1     |
# |motorcar:conditional                         |1     |
# |verify                                       |1     |
# |payment:litecoin                             |1     |
# |phone:2                                      |1     |
# |addr:inclusion                               |1     |
# |historic:civilisation                        |1     |
# |name:sw                                      |1     |
# |name:gsw                                     |1     |
# |office_1                                     |1     |
# |operator:branch                              |1     |
# |website_3                                    |1     |
# |amenity_2                                    |1     |
# |wetap:status                                 |1     |
# |url:mek.oszk                                 |1     |
# |communication:lte                            |1     |
# |health_specialty:obstetrics                  |1     |
# |fuel:95                                      |1     |
# |utility                                      |1     |
# |carpenter                                    |1     |
# |name:sa                                      |1     |
# |railway:signal:distant:shortened:distance    |1     |
# |url:wikimapia                                |1     |
# |biergarten                                   |1     |
# |name:ceb                                     |1     |
# |name:kw                                      |1     |
# |shoes                                        |1     |
# |checkpoint_type                              |1     |
# |ref:transformer:old                          |1     |
# |animal_shelter                               |1     |
# |nam                                          |1     |
# |name:av                                      |1     |
# |collection_times:signed                      |1     |
# |ref:bkk_1                                    |1     |
# |service:gaming                               |1     |
# |name:gd                                      |1     |
# |bicycle_rental                               |1     |
# |official_name:sv                             |1     |
# |disused:communication:wlan                   |1     |
# |name:sm                                      |1     |
# |building:levels:aboveground                  |1     |
# |diet:kosher                                  |1     |
# |frequency:LHBS                               |1     |
# |name:ks                                      |1     |
# |abandoned:brand                              |1     |
# |source:sqkm                                  |1     |
# |object                                       |1     |
# |sailboat_rental                              |1     |
# |url:mvte                                     |1     |
# |capacity:hgv                                 |1     |
# |payment:discover_card                        |1     |
# |name:su                                      |1     |
# |internet_access:access                       |1     |
# |recycling:electronics                        |1     |
# |fire_hydrant:couplings                       |1     |
# |Icn                                          |1     |
# |level_crossing:light                         |1     |
# |alt_name:ro                                  |1     |
# |obstacle:wheelchair                          |1     |
# |url:kulcsoshaz                               |1     |
# |name:lzh                                     |1     |
# |addr:region:hu                               |1     |
# |abandoned:backrest                           |1     |
# |open_air                                     |1     |
# |url:11161                                    |1     |
# |dog:description                              |1     |
# |memorial:subject                             |1     |
# |name:to                                      |1     |
# |toys:model_railway                           |1     |
# |rwetempcharging_station:plug                 |1     |
# |monitoring_station                           |1     |
# |name:ba                                      |1     |
# |name:dz                                      |1     |
# |map                                          |1     |
# |name:xal                                     |1     |
# |drinkable                                    |1     |
# |musical_instrument                           |1     |
# |ref:oebb                                     |1     |
# |opening                                      |1     |
# |name:gv                                      |1     |
# |name:bpy                                     |1     |
# |bic                                          |1     |
# |payment:laser                                |1     |
# |recycling:bottles                            |1     |
# |service:photo                                |1     |
# |alt_name:lfn                                 |1     |
# |name_2                                       |1     |
# |inscription:1                                |1     |
# |seamark:status                               |1     |
# |seamark:small_craft_facility:category        |1     |
# |source_date                                  |1     |
# |removed:drinking_water                       |1     |
# |fm_radio                                     |1     |
# |monitoring:seismic_activity                  |1     |
# |shoe_repair                                  |1     |
# |function                                     |1     |
# |name:kaa                                     |1     |
# |currency:BTC                                 |1     |
# |source:fee                                   |1     |
# |mattress                                     |1     |
# |name:ay                                      |1     |
# |car_service                                  |1     |
# |old_landuse                                  |1     |
# |ref:ibnr                                     |1     |
# |fee:price                                    |1     |
# |addr:place:hu                                |1     |
# |source:old_name                              |1     |
# |source:seats                                 |1     |
# |name:vec                                     |1     |
# |sells                                        |1     |
# |recycling:electronic_scrap                   |1     |
# |tower:type_1                                 |1     |
# |real_ale                                     |1     |
# |nat_name                                     |1     |
# |callsign                                     |1     |
# |billiards:snooker                            |1     |
# |garden:style                                 |1     |
# |destroyed:historic                           |1     |
# |traffic_sign:2                               |1     |
# |description:2016                             |1     |
# |dog:opening_hours                            |1     |
# |author                                       |1     |
# |zoo                                          |1     |
# |ULPIA                                        |1     |
# |measurement                                  |1     |
# |recycling:copper                             |1     |
# |seamark:notice:4:orientation                 |1     |
# |clothes:men                                  |1     |
# |name:kg                                      |1     |
# |name:bcl                                     |1     |
# |codul_entității_muzeale                      |1     |
# |proposed:barrier                             |1     |
# |sport:table_soccer                           |1     |
# |musical_instrument:parts                     |1     |
# |geonames:id                                  |1     |
# |recycling:light_bulbs                        |1     |
# |sqkm                                         |1     |
# |capital_ISO3166-1                            |1     |
# |internet_access:description                  |1     |
# |age                                          |1     |
# |flickr                                       |1     |
# |high                                         |1     |
# |beer_garden                                  |1     |
# |seamark:wreck:depth                          |1     |
# |name:roa-rup                                 |1     |
# |place_of_worship                             |1     |
# |name:bm                                      |1     |
# |levels                                       |1     |
# |floating                                     |1     |
# |person:date_of_death                         |1     |
# |compressed_air:fee                           |1     |
# |furniture                                    |1     |
# |wikipedia:pl                                 |1     |
# |cat                                          |1     |
# |obstruction                                  |1     |
# |facebook:hu                                  |1     |
# |name:ilo                                     |1     |
# |des                                          |1     |
# |name:rw                                      |1     |
# |bijou                                        |1     |
# |railway:name:SŽ                              |1     |
# |name:nrm                                     |1     |
# |stamps                                       |1     |
# |scout                                        |1     |
# |official_name:sk                             |1     |
# |enforcement                                  |1     |
# |name:lad                                     |1     |
# |url:1961                                     |1     |
# |hours                                        |1     |
# |url:tuosm                                    |1     |
# |name:kab                                     |1     |
# |url:borzsony938m.blog                        |1     |
# |opening_hours:hu                             |1     |
# |landmark                                     |1     |
# |local_name                                   |1     |
# |recycling:plastic_bags                       |1     |
# |sanitary_dump_station:gravity                |1     |
# |name:roa-tara                                |1     |
# |crane:maxradius                              |1     |
# |url:vadonszava                               |1     |
# |alt_name:uk                                  |1     |
# |bucker                                       |1     |
# |communications_transponder:modulation        |1     |
# |name:lg                                      |1     |
# |est_height                                   |1     |
# |disused:power                                |1     |
# |name:ne                                      |1     |
# |url:museum                                   |1     |
# |name:co                                      |1     |
# |ele:source                                   |1     |
# |abandoned_name                               |1     |
# |abandoned:wheelchair                         |1     |
# |name:ak                                      |1     |
# |name:ts                                      |1     |
# |name:hak                                     |1     |
# |service:fax                                  |1     |
# |name:io                                      |1     |
# |old_name:hu:2001-2016                        |1     |
# |url:lexikon.katolikus                        |1     |
# |addr2:street                                 |1     |
# |construction:amenity                         |1     |
# |contact:website:en                           |1     |
# |turn:lanes                                   |1     |
# |incline                                      |1     |
# |symbol:hu                                    |1     |
# |url:szallas                                  |1     |
# |award:hotelstars                             |1     |
# |official_name:lv                             |1     |
# |source:delivery_date                         |1     |
# |name:tk                                      |1     |
# |railway:signal:stop:height                   |1     |
# |crane:operator                               |1     |
# |oneway                                       |1     |
# |tree:diameter                                |1     |
# |name:cy                                      |1     |
# |river:waterway_distance                      |1     |
# |url:bacskiskun                               |1     |
# |service:vehicle:audio                        |1     |
# |wikimedia                                    |1     |
# |lunch:menu:delivery:fee                      |1     |
# |url:zmne                                     |1     |
# |addr:city:en                                 |1     |
# |lunch:menu:daily_special                     |1     |
# |name:old                                     |1     |
# |passenger_lines                              |1     |
# |name:jbo                                     |1     |
# |hygrometer                                   |1     |
# |name:zh_pinyin                               |1     |
# |seamark:beacon_lateral:impact                |1     |
# |demolished:tower                             |1     |
# |owncup_discount                              |1     |
# |name:sg                                      |1     |
# |books:language:eo                            |1     |
# |Label                                        |1     |
# |man                                          |1     |
# |lcn                                          |1     |
# |water_volume                                 |1     |
# |tourism_1                                    |1     |
# |Megjegyzes                                   |1     |
# |note2                                        |1     |
# |cooking                                      |1     |
# |name:ltg                                     |1     |
# |removed:name                                 |1     |
# |source_ref                                   |1     |
# |country_code_iso3166_1_alpha_2               |1     |
# |raceway                                      |1     |
# |payment:meal_vouchers                        |1     |
# |monitoring:gps                               |1     |
# |railway:name                                 |1     |
# |liaison                                      |1     |
# |phone:Monitor_service                        |1     |
# |amenity:disused                              |1     |
# |service:bicycle:screwdriver                  |1     |
# |milestone_type                               |1     |
# |official_name:sr                             |1     |
# |diet:raw                                     |1     |
# |strazakosm:sender_id                         |1     |
# |name:hsb                                     |1     |
# |old_tourism                                  |1     |
# |windmill:vanes                               |1     |
# |descr                                        |1     |
# |name:ff                                      |1     |
# |fountain                                     |1     |
# |name:ha                                      |1     |
# |computer:repair                              |1     |
# |phone_3                                      |1     |
# |tourism_survey                               |1     |
# |phone:parts                                  |1     |
# |clothes:denim                                |1     |
# |picture                                      |1     |
# |ice_cream:type                               |1     |
# |url:kesportal                                |1     |
# |sound                                        |1     |
# |inscription:de                               |1     |
# |camera:make                                  |1     |
# |name:nds                                     |1     |
# |source:height                                |1     |
# |name:lij                                     |1     |
# |tactile_writing:braille:lg                   |1     |
# |rf:category                                  |1     |
# |ref:hu_geocaching                            |1     |
# |obstacle:motorcar                            |1     |
# |heritage:website                             |1     |
# |phone:beauty                                 |1     |
# |railway:signal:electricity:height            |1     |
# |payment:bancomat                             |1     |
# |payment:creditcard                           |1     |
# |url:archeodatabase                           |1     |
# |user_defined_other                           |1     |
# |authentication:nfc                           |1     |
# |fixme_1                                      |1     |
# |level_crossing:traffic_signals               |1     |
# |service:photography                          |1     |
# |disused:contact:website                      |1     |
# |seamark:notice:1:distance_start              |1     |
# |source:addr:date                             |1     |
# |letter_box:type                              |1     |
# |ethanol                                      |1     |
# |atm:bitcoin                                  |1     |
# |shop:disused                                 |1     |
# |name:tzl                                     |1     |
# |ISO3166-2                                    |1     |
# |url:1                                        |1     |
# |old_name:uk                                  |1     |
# |HU:hu-go:milestone_1                         |1     |
# |alt_name_1                                   |1     |
# |short_name:hu                                |1     |
# |blind:description:en                         |1     |
# |link                                         |1     |
# |social_facility_for                          |1     |
# |health_person                                |1     |
# |price                                        |1     |
# |official_name:ru                             |1     |
# |seamark:notice:5:function                    |1     |
# |athletics:hammer_throw                       |1     |
# |name:rm                                      |1     |
# |pump:type                                    |1     |
# |name:pnt                                     |1     |
# |official_name:lt                             |1     |
# |busway:right                                 |1     |
# |crossing_2                                   |1     |
# |ramp:wheelchair                              |1     |
# |old:addr:street                              |1     |
# |name:ie                                      |1     |
# |lunch:menu:main                              |1     |
# |bicycle:conditional                          |1     |
# |inscription:eo                               |1     |
# |Operator                                     |1     |
# |name:so                                      |1     |
# |currency                                     |1     |
# |name:wo                                      |1     |
# |floor                                        |1     |
# |name:tok                                     |1     |
# |backcountry                                  |1     |
# |abandoned:railway:signal:main:form           |1     |
# |name:bi                                      |1     |
# |disused:internet_access:ssid                 |1     |
# |areasize:sqm                                 |1     |
# |roof:material                                |1     |
# |opening_hours:note                           |1     |
# |old_name:en                                  |1     |
# |abandoned:service:bicycle:retail             |1     |
# |motorcycle:sales                             |1     |
# |alt_name:cs                                  |1     |
# |lunch:buffet:cost                            |1     |
# |note:sk                                      |1     |
# |psc                                          |1     |
# |url:onkormanyzat.net                         |1     |
# |wikimedia_commons                            |1     |
# |motorcycle:clothes                           |1     |
# |ele:relative                                 |1     |
# |abandoned_place                              |1     |
# |abandoned:phone                              |1     |
# |format:top                                   |1     |
# |abandoned:start_date                         |1     |
# |railway:signal:stop                          |1     |
# |name:chr                                     |1     |
# |license_classes                              |1     |
# |manometer                                    |1     |
# |ref:internal                                 |1     |
# |seamark:control_point:category               |1     |
# |fortification                                |1     |
# |temperature                                  |1     |
# |gender                                       |1     |
# |name:nan                                     |1     |
# |planted_date                                 |1     |
# |proposed:communication:mobile_phone          |1     |
# |lgbtq                                        |1     |
# |crane:ship:maxdraft                          |1     |
# |code                                         |1     |
# |abandoned:aeroway                            |1     |
# |obelisk:size                                 |1     |
# |gsm:BSIC                                     |1     |
# |addr:old_housenumber                         |1     |
# |mobile_phone:repair                          |1     |
# |high_ropes_course                            |1     |
# |sour                                         |1     |
# |sport:pinball                                |1     |
# |clothes:wedding                              |1     |
# |source:addr:postcode                         |1     |
# |service:vehicle:air_conditioning             |1     |
# |disused:contact:phone                        |1     |
# |tower:material                               |1     |
# |demolished:building                          |1     |
# |payment:paypass                              |1     |
# |umtd:RNC                                     |1     |
# |url:booking                                  |1     |
# |planted_by                                   |1     |
# |abandoned:craft                              |1     |
# |foot:conditional                             |1     |
# |camera:model                                 |1     |
# |name:als                                     |1     |
# |url:kozterkep.hu                             |1     |
# |socket:type1_combo                           |1     |
# |fuel:propane                                 |1     |
# |disused:aeroway                              |1     |
# |name:scn                                     |1     |
# |diet:no_sugar                                |1     |
# |dog:maxweight                                |1     |
# |light:tilt                                   |1     |
# |name:pa                                      |1     |
# |official_name:vi                             |1     |
# |wellness                                     |1     |
# |alt_name:vi                                  |1     |
# |communication:umts                           |1     |
# |fuel:ethanol                                 |1     |
# |demolished:man_made                          |1     |
# |name:pih                                     |1     |
# |phone:HU                                     |1     |
# |ethnicity                                    |1     |
# |seamark:building:function                    |1     |
# |name:fiu-vro                                 |1     |
# |artwork:type                                 |1     |
# |service:computer:network                     |1     |
# |name:pam                                     |1     |
# |generator:output:hot_water                   |1     |
# |braille                                      |1     |
# |opening_hours:members                        |1     |
# |ref2:bkk                                     |1     |
# |planned                                      |1     |
# |sign                                         |1     |
# |headframe                                    |1     |
# |nature                                       |1     |
# |pump:status                                  |1     |
# |website:hu                                   |1     |
# |phone:ügyelet                                |1     |
# |removed:tourism                              |1     |
# |official_name:es                             |1     |
# |payment:bankaxess                            |1     |
# |abandoned:recycling_type                     |1     |
# |flashing_lights                              |1     |
# |url:egkep                                    |1     |
# |building:levels:underground                  |1     |
# |ref:OM                                       |1     |
# |socket:type1                                 |1     |
# |crossing:lights                              |1     |
# |email:alt                                    |1     |
# |table                                        |1     |
# |disused:ford                                 |1     |
# |internet_access:ssid_1                       |1     |
# |ref_1                                        |1     |
# |phone:2016                                   |1     |
# |name:ky                                      |1     |
# |name:cu                                      |1     |
# |alt_name2                                    |1     |
# |url:kisvasut                                 |1     |
# |name:pcd                                     |1     |
# |church_ale                                   |1     |
# |url:Csepel                                   |1     |
# |service:bicycle:ebike                        |1     |
# |communication:antenna                        |1     |
# |truck                                        |1     |
# |windmill:type                                |1     |
# |ref:HU:edid                                  |1     |
# |name:lez                                     |1     |
# |name:nv                                      |1     |
# |source:direction                             |1     |
# |generator:output:heat                        |1     |
# |building_type                                |1     |
# |blind                                        |1     |
# |material:hu                                  |1     |
# |blind:description:hu                         |1     |
# |genus:de                                     |1     |
# |security                                     |1     |
# |wikipedia:hu                                 |1     |
# |demolished:natural                           |1     |
# |url:metrodom                                 |1     |
# |service:vehicle:used_car_sales               |1     |
# |service:vehicle:truck_repair                 |1     |
# |computer:type                                |1     |
# |service:vehicle:new_car                      |1     |
# |in_in:city                                   |1     |
# |name:rmy                                     |1     |
# |addr:orig_street                             |1     |
# |safety_rope                                  |1     |
# |parfum                                       |1     |
# |cuisine_1                                    |1     |
# |name:wuu                                     |1     |
# |clothes:sports                               |1     |
# |diet:no_lacto                                |1     |
# |alt_phone                                    |1     |
# |alt_name:eo                                  |1     |
# |old_name:vi                                  |1     |
# |name:ee                                      |1     |
# |currency:XBT                                 |1     |
# |photographic_laboratory                      |1     |
# |seamark:conspicuity                          |1     |
# |fuel:100LL                                   |1     |
# |url:3                                        |1     |
# |website_old                                  |1     |
# |ISO3166-1                                    |1     |
# |description:sr                               |1     |
# |sells:tobacco                                |1     |
# |missing:information                          |1     |
# |diet:halal                                   |1     |
# |target                                       |1     |
# |wires                                        |1     |
# |shop:photo                                   |1     |
# |name:kbd                                     |1     |
# |farm                                         |1     |
# |name:ti                                      |1     |
# |it:type                                      |1     |
# |loc_name:en                                  |1     |
# |disused:communication:mobile_phone           |1     |
# |ref:HU:spar                                  |1     |
# |name:mi                                      |1     |
# |building:disused                             |1     |
# |source:noexit                                |1     |
# |location:communication:tower                 |1     |
# |ref:mobile_phone                             |1     |
# |motorcycle:theme                             |1     |
# |photo_printing                               |1     |
# |bulk_purchase                                |1     |
# |capacity:bus                                 |1     |
# |esr:user                                     |1     |
# |seamark:notice:5:category                    |1     |
# |abandoned:operator                           |1     |
# |sport_2                                      |1     |
# |share_taxi                                   |1     |
# |lunch:menu:course:drink                      |1     |
# |source:link                                  |1     |
# |ref:posta                                    |1     |
# |name:hif                                     |1     |
# |destroyed:tourism                            |1     |
# |ref:at:bda                                   |1     |
# |source:office                                |1     |
# |motorhome                                    |1     |
# |addr:region                                  |1     |
# |email:2                                      |1     |
# |disused:surface                              |1     |
# |old_name:tr                                  |1     |
# |post:unit                                    |1     |
# |fuel:gasoline                                |1     |
# |payment:debit_cards:minimum                  |1     |
# |access:disabled                              |1     |
# |checkpoint:name                              |1     |
# |name:tl                                      |1     |
# |name:sn                                      |1     |
# |strike_tone                                  |1     |
# |phone:Notebook_service                       |1     |
# |addr:place:sl                                |1     |
# |description:1                                |1     |
# |lockabel                                     |1     |
# |lunch:buffet:url                             |1     |
# |url:Nagymaros                                |1     |
# |health_facility                              |1     |
# |gun_emplacement_type                         |1     |
# |employment_agency:type                       |1     |
# |exhibit                                      |1     |
# |dinghy_rental                                |1     |
# |name:km                                      |1     |
# |staff                                        |1     |
# |name:ki                                      |1     |
# |name:kl                                      |1     |
# |strazakosm:send_date                         |1     |
# |url:mno                                      |1     |
# |official_name:ja                             |1     |
# |phone:mobile                                 |1     |
# |url:pilisrejtely                             |1     |
# |seamark:construction                         |1     |
# |url:1967                                     |1     |
# |wikipedia:de                                 |1     |
# |open_fire                                    |1     |
# |tv:seasonal                                  |1     |
# |bicycle:repair                               |1     |
# |service:vehicle:body_repair                  |1     |
# |recycling:electronic_items                   |1     |
# |name:ge                                      |1     |
# |motorcycle:parts                             |1     |
# |nwn_ref                                      |1     |
# |website:2                                    |1     |
# |pump_style                                   |1     |
# |name:bxr                                     |1     |
# |official_name:hu                             |1     |
# |name:rue                                     |1     |
# |minor_substation                             |1     |
# |capacity:wheelchair                          |1     |
# |url:gmap                                     |1     |
# |GPS                                          |1     |
# |removed:information                          |1     |
# |wheelchair:description:de                    |1     |
# |old_name:-1951                               |1     |
# |potable                                      |1     |
# |stairs                                       |1     |
# |room:type                                    |1     |
# |socket:type3                                 |1     |
# |contact:fax_1                                |1     |
# |service:bicycle:service                      |1     |
# |name:ksh                                     |1     |
# |source:material                              |1     |
# |name:mzn                                     |1     |
# |okt:milestone:name                           |1     |
# |information:map                              |1     |
# |lunch:menu:dessert                           |1     |
# |payment:union_card                           |1     |
# |entry                                        |1     |
# |name:xmf                                     |1     |
# |engraving                                    |1     |
# |name:frr                                     |1     |
# |name:ln                                      |1     |
# |artisan                                      |1     |
# |ope                                          |1     |
# |url:hnp                                      |1     |
# |name:na                                      |1     |
# |name:si                                      |1     |
# |model:rc_model                               |1     |
# |crop                                         |1     |
# |sanitary_dump_station:chemical_toilet        |1     |
# |short_name:cs                                |1     |
# |name:ia                                      |1     |
# |railway:signal                               |1     |
# |name:arc                                     |1     |
# |name:ang                                     |1     |
# |monitoring:lightning                         |1     |
# |ref:isil                                     |1     |
# |name:vls                                     |1     |
# |bolt                                         |1     |
# |skype                                        |1     |
# |cocktails                                    |1     |
# |abandoned:service:bicycle:repair             |1     |
# |service:bicycle:note                         |1     |
# |ref:viztorony.hu                             |1     |
# |clothes:children                             |1     |
# |communication:gsm                            |1     |
# |name:ab                                      |1     |
# |dir                                          |1     |
# |fuel:octane_80                               |1     |
# |name:pap                                     |1     |
# |website2                                     |1     |
# |SIRUTA:code                                  |1     |
# |building:use                                 |1     |
# |id                                           |1     |
# |group_only                                   |1     |
# |aerial                                       |1     |
# |opening_date                                 |1     |
# |url:oszk                                     |1     |
# |building:architecture                        |1     |
# |water_slide                                  |1     |
# |bike                                         |1     |
# |name:stq                                     |1     |
# |waste_1                                      |1     |
# |name:fur                                     |1     |
# |amenity:removed                              |1     |
# |official_name:pl                             |1     |
# |url:blog                                     |1     |
# |seamark:reflectivity                         |1     |
# |url:ceginfo                                  |1     |
# |name:st                                      |1     |
# |memorial_1                                   |1     |
# |socket:tesla_supercharger                    |1     |
# |community_centre:for                         |1     |
# |chimney:shape                                |1     |
# |turn:lanes:backward                          |1     |
# |fixme:tower:construction                     |1     |
# |since                                        |1     |
# |species:nl                                   |1     |
# |url:11168                                    |1     |
# |weight                                       |1     |
# |payment:huf                                  |1     |
# |opening_hours:happy_hour                     |1     |
# |name_alt                                     |1     |
# |official_name:id                             |1     |
# |top_up:posta_csekk                           |1     |
# |monitoring:particulate_matter                |1     |
# |background_music                             |1     |
# |age_group                                    |1     |
# |abandoned:entrance                           |1     |
# |communication:mobile                         |1     |
# |official_name:be                             |1     |
# |hrsz                                         |1     |
# |hov                                          |1     |
# |happy_hours:description                      |1     |
# |planned:place                                |1     |
# |name:te                                      |1     |
# |breast                                       |1     |
# |capital_city                                 |1     |
# |river:category_distance                      |1     |
# |official_name:el                             |1     |
# |checkpoint:hiking                            |1     |
# |advertisement                                |1     |
# |railway:signal:distant:shortened             |1     |
# |country_code_fips                            |1     |
# |bus_stop:category                            |1     |
# |disabled_spaces                              |1     |
# |person:date_of_birth                         |1     |
# |name:nap                                     |1     |
# |construction:man_made                        |1     |
# |url:bushcraft                                |1     |
# |sanitary_dump_station:grey_water             |1     |
# |size                                         |1     |
# |official_name:it                             |1     |
# |is_in:                                       |1     |
# |name:pag                                     |1     |
# |Állapot                                      |1     |
# |historic:landuse                             |1     |
# |abandoned:power                              |1     |
# |distillery                                   |1     |
# |payment                                      |1     |
# |description:hr                               |1     |
# |name:de_1                                    |1     |
# |library                                      |1     |
# |hairdye                                      |1     |
# |disused:information                          |1     |
# |inscription:3                                |1     |
# |umts:psc                                     |1     |
# |abandoned:cuisine                            |1     |
# |kindergarten                                 |1     |
# |footway                                      |1     |
# |craft_1                                      |1     |
# |demolished:museum                            |1     |
# |name:jv                                      |1     |
# |ref:ruian:addr                               |1     |
# |internet_access:ssid_2                       |1     |
# |name:lfn                                     |1     |
# |disused:craft                                |1     |
# |opening_hours:conditional                    |1     |
# |openplaques:id                               |1     |
# |name:rn                                      |1     |
# |addr:street:hu                               |1     |
# |name:yo                                      |1     |
# |is_in:iso_3166_2                             |1     |
# |was:amenity                                  |1     |
# |crane:ship:maxlength                         |1     |
# |premium_diesel                               |1     |
# |piste:difficulty                             |1     |
# |disused:wheelchair                           |1     |
# |name:mg                                      |1     |
# |name:ext                                     |1     |
# |old_brand                                    |1     |
# |music                                        |1     |
# |collector                                    |1     |
# |access:hgv                                   |1     |
# |happy_hours:food                             |1     |
# |access:description                           |1     |
# |full_name                                    |1     |
# |was:shop                                     |1     |
# |name:eml                                     |1     |
# |umts                                         |1     |
# |url:mtak                                     |1     |
# |payment:euro                                 |1     |
# |drink:beer                                   |1     |
# |obstacle:bicycle                             |1     |
# |name:nah                                     |1     |
# |denomination:1300-1600                       |1     |
# |phone:porta                                  |1     |
# |ref:gurs:hs_mid                              |1     |
# |recycling:tyres                              |1     |
# |name:nds-nl                                  |1     |
# |addr:house                                   |1     |
# |official_name:et                             |1     |
# |abandoned:landuse                            |1     |
# |legal                                        |2     |
# |bicycle:source                               |2     |
# |inscription:n                                |2     |
# |ref:volan                                    |2     |
# |name:mrj                                     |2     |
# |alt_name:ru                                  |2     |
# |railway:signal:distant:repeated:form         |2     |
# |seamark:notice:3:orientation                 |2     |
# |seamark:beacon_isolated_danger:colour_pattern|2     |
# |weather:soil_thermometer                     |2     |
# |url:velenceito                               |2     |
# |name:myv                                     |2     |
# |name:my                                      |2     |
# |operational_status                           |2     |
# |museum                                       |2     |
# |loc_name:de                                  |2     |
# |block                                        |2     |
# |window                                       |2     |
# |name:kk                                      |2     |
# |ski                                          |2     |
# |roof:colour                                  |2     |
# |name:qu                                      |2     |
# |phone:HU:mobile                              |2     |
# |name:bar                                     |2     |
# |protection_title                             |2     |
# |model:static_kit                             |2     |
# |climbing:rock                                |2     |
# |toilets:hot_water                            |2     |
# |dance:style                                  |2     |
# |disused:postal_code                          |2     |
# |name:ht                                      |2     |
# |diplomatic:sending_country                   |2     |
# |segregated                                   |2     |
# |note:de                                      |2     |
# |name:krc                                     |2     |
# |disused:phone                                |2     |
# |recycling:rubble                             |2     |
# |name:nov                                     |2     |
# |name:pms                                     |2     |
# |vending_machine                              |2     |
# |seamark:harbour:category                     |2     |
# |artist:wikidata                              |2     |
# |railway:signal:main_repeated:states          |2     |
# |weather:ombrometer                           |2     |
# |weather:sunshine_recorder                    |2     |
# |name:fy                                      |2     |
# |description:ro                               |2     |
# |messenger                                    |2     |
# |highway_2                                    |2     |
# |service:bicycle:sales                        |2     |
# |golf:course                                  |2     |
# ...
# |url:miserend                                 |174   |
# |maxspeed                                     |174   |
# |seamark:light:period                         |175   |
# |railway:signal:catenary_mast                 |176   |
# |seamark:notice:1:function                    |179   |
# |seamark:notice:2:impact                      |179   |
# |addr:place                                   |179   |
# |seamark:notice:1:impact                      |179   |
# |seamark:notice:2:function                    |179   |
# |seamark:notice:1:category                    |180   |
# |railway:turnout_side                         |180   |
# |seamark:notice:2:category                    |180   |
# |phases                                       |181   |
# |fuel:diesel                                  |182   |
# |recycling:clothes                            |186   |
# |toilets:disposal                             |193   |
# |button_operated                              |202   |
# |railway:switch:electric                      |203   |
# |ref:vatin:hu                                 |207   |
# |ref:kisalfold                                |209   |
# |water_source                                 |210   |
# |abandoned:amenity                            |210   |
# |bollard                                      |211   |
# |frequency                                    |211   |
# |dispensing                                   |213   |
# |payment:visa                                 |215   |
# |description:en                               |218   |
# |addr:housename                               |218   |
# |seamark:light:exhibition                     |219   |
# |drive_through                                |221   |
# |street_cabinet                               |222   |
# |payment:mastercard                           |230   |
# |layer                                        |233   |
# |payment:telephone_cards                      |234   |
# |location:transition                          |242   |
# |healthcare                                   |242   |
# |seamark:light:category                       |242   |
# |source:addr:housenumber                      |243   |
# |seamark:buoy_lateral:reflectivity            |244   |
# |generator:type                               |251   |
# |railway:local_operated                       |251   |
# |payment:contactless                          |254   |
# |source:addr:street                           |256   |
# |attraction                                   |258   |
# |disused                                      |262   |
# |local_ref                                    |264   |
# |generator:method                             |268   |
# |tower:structure                              |271   |
# |railway:signal:direction                     |276   |
# |railway:signal:position                      |278   |
# |map_size                                     |285   |
# |pump                                         |287   |
# |fax                                          |293   |
# |surveillance:zone                            |296   |
# |fireplace                                    |298   |
# |delivery                                     |307   |
# |recycling:glass_bottles                      |319   |
# |internet_access:fee                          |320   |
# |train                                        |346   |
# |playground                                   |348   |
# |ruins                                        |349   |
# |source:name                                  |349   |
# |voltage                                      |350   |
# |recycling:plastic                            |352   |
# |seamark:distance_mark:units                  |367   |
# |seamark:distance_mark:category               |367   |
# |seamark:distance_mark:distance               |367   |
# |ref:MTSZ                                     |368   |
# |generator:source                             |369   |
# |water                                        |369   |
# |camera:mount                                 |374   |
# |branch:type                                  |380   |
# |seamark:buoy_lateral:category                |381   |
# |seamark:buoy_lateral:colour                  |381   |
# |seamark:buoy_lateral:shape                   |381   |
# |map_type                                     |386   |
# |railway:position                             |388   |
# |dog                                          |390   |
# |motorcycle                                   |392   |
# |payment:cash                                 |393   |
# |description:hu                               |394   |
# |seamark:notice:addition                      |397   |
# |kerb                                         |399   |
# |lit                                          |401   |
# |disused:amenity                              |405   |
# |seamark:light:character                      |407   |
# |payment:notes                                |408   |
# |seamark:light:colour                         |414   |
# |camera:type                                  |416   |
# |species                                      |417   |
# |waterway                                     |429   |
# |indoor                                       |429   |
# |crossing:light                               |451   |
# |horse                                        |451   |
# |wheelchair:description                       |455   |
# |name:it                                      |456   |
# |converted_by                                 |465   |
# |bin                                          |475   |
# |cemetery                                     |481   |
# |crossing:barrier                             |482   |
# |source:ele                                   |485   |
# |takeaway                                     |498   |
# |recycling:cans                               |499   |
# |landuse                                      |504   |
# |motorcar                                     |521   |
# |payment:credit_cards                         |535   |
# |course                                       |542   |
# |name:hr                                      |548   |
# |surveillance                                 |558   |
# |shelter_type                                 |564   |
# |seamark:notice:orientation                   |564   |
# |payment:debit_cards                          |575   |
# |structure                                    |585   |
# |waste                                        |594   |
# |contact:facebook                             |596   |
# |surveillance:type                            |604   |
# |recycling:glass                              |613   |
# |addr:streetnumber                            |623   |
# |motor_vehicle                                |641   |
# |ref:derke                                    |652   |
# |craft                                        |682   |
# |supervised                                   |695   |
# |checkpoint:type                              |705   |
# |checkpoint                                   |707   |
# |contact:email                                |721   |
# |smoking                                      |725   |
# |name:sk                                      |730   |
# |seamark:notice:category                      |743   |
# |outdoor_seating                              |743   |
# |facebook                                     |749   |
# |taxon:en                                     |753   |
# |surface                                      |777   |
# |parking                                      |779   |
# |seamark:notice:impact                        |785   |
# |seamark:notice:function                      |787   |
# |taxon:genus                                  |788   |
# |recycling:paper                              |805   |
# |taxon                                        |820   |
# |transformer                                  |828   |
# |design                                       |843   |
# |stopColorType                                |846   |
# |old_name                                     |854   |
# |atm                                          |857   |
# |drinking_water                               |904   |
# |wikidata                                     |913   |
# |aeroway                                      |921   |
# |traffic_signals:direction                    |971   |
# |wikipedia                                    |1006  |
# |advertising                                  |1009  |
# |artist_name                                  |1034  |
# |addr:district                                |1047  |
# |inscription                                  |1053  |
# |traffic_signals                              |1069  |
# |ref:vodafone                                 |1078  |
# |payment:coins                                |1086  |
# |import_ref                                   |1100  |
# |contact:website                              |1173  |
# |internet_access                              |1175  |
# |level                                        |1205  |
# |pole:type                                    |1213  |
# |hiking                                       |1233  |
# |ford                                         |1235  |
# |vending                                      |1276  |
# |umts:PSC                                     |1287  |
# |ref:mav                                      |1318  |
# |sport                                        |1360  |
# |fee                                          |1444  |
# |name:en                                      |1445  |
# |mapillary                                    |1453  |
# |recycling_type                               |1475  |
# |seats                                        |1479  |
# |contact:phone                                |1498  |
# |name:de                                      |1503  |
# |addr:conscriptionnumber                      |1509  |
# |fire_hydrant:diameter                        |1597  |
# |height                                       |1598  |
# |lines                                        |1632  |
# |tactile_paving                               |1755  |
# |is_in:country                                |1807  |
# |brand                                        |1812  |
# |name:ru                                      |1822  |
# |name:hu                                      |1833  |
# |office                                       |1855  |
# |network                                      |1860  |
# |denomination                                 |1861  |
# |alt_name                                     |1892  |
# |board_type                                   |1896  |
# |artwork_type                                 |1958  |
# |is_in:subregion                              |1963  |
# |is_in:county                                 |1974  |
# |location                                     |2004  |
# |colour                                       |2030  |
# |seamark:type                                 |2038  |
# |substance                                    |2059  |
# |bicycle_parking                              |2179  |
# |traffic_sign                                 |2208  |
# |pipeline                                     |2253  |
# |lte:LAC                                      |2327  |
# |lte:eNB                                      |2333  |
# |lte:cellid                                   |2334  |
# |religion                                     |2378  |
# |distance                                     |2381  |
# |support                                      |2397  |
# |source:postal_code:date                      |2470  |
# |umts:RNC                                     |2545  |
# |umts:LAC                                     |2549  |
# |umts:cellid                                  |2552  |
# |email                                        |2605  |
# |memorial                                     |2694  |
# |addr:province                                |2782  |
# |gsm:LAC                                      |2792  |
# |gsm:cellid                                   |2793  |
# |cuisine                                      |2802  |
# |capacity                                     |2989  |
# |addr:suburb                                  |3064  |
# |traffic_calming                              |3108  |
# |source:postal_code                           |3128  |
# |covered                                      |3149  |
# |ksh_ref                                      |3179  |
# |MNC                                          |3188  |
# |source:population:date                       |3200  |
# |source:population                            |3210  |
# |MCC                                          |3334  |
# |note                                         |3354  |
# |building                                     |3429  |
# |population                                   |3444  |
# |postal_code                                  |3478  |
# |HU:hu-go:milestone                           |3483  |
# |HU:hu-go:road                                |3483  |
# |foot                                         |3673  |
# |tower:type                                   |3796  |
# |ele                                          |4002  |
# |bicycle                                      |4029  |
# |crossing_ref                                 |4212  |
# |backrest                                     |4244  |
# |communication:mobile_phone                   |4306  |
# |verified                                     |4568  |
# |fire_hydrant:position                        |4838  |
# |bench                                        |4860  |
# |start_date                                   |5092  |
# |survey:date                                  |5259  |
# |toilets:wheelchair                           |5306  |
# |leisure                                      |5707  |
# |access                                       |5781  |
# |bus                                          |5919  |
# |ref:bkk                                      |5998  |
# |noexit                                       |6139  |
# |information                                  |6397  |
# |created_by                                   |6610  |
# |material                                     |7127  |
# |is_in                                        |7146  |
# |direction                                    |7157  |
# |phone                                        |7500  |
# |fire_hydrant:type                            |8051  |
# |ref                                          |9845  |
# |shelter                                      |9995  |
# |emergency                                    |11287 |
# |description                                  |11340 |
# |opening_hours                                |11805 |
# |website                                      |12096 |
# |crossing                                     |12139 |
# |public_transport                             |12604 |
# |entrance                                     |12696 |
# |historic                                     |14756 |
# |man_made                                     |14872 |
# |denotation                                   |15011 |
# |addr:country                                 |16109 |
# |railway                                      |16724 |
# |place                                        |17171 |
# |wheelchair                                   |18600 |
# |leaf_cycle                                   |18967 |
# |leaf_type                                    |19245 |
# |barrier                                      |19864 |
# |tourism                                      |20699 |
# |fixme                                        |25431 |
# |operator                                     |25704 |
# |shop                                         |25978 |
# |natural                                      |45722 |
# |source:date                                  |49548 |
# |url                                          |61261 |
# |highway                                      |71781 |
# |addr:housenumber                             |75047 |
# |addr:postcode                                |77041 |
# |addr:city                                    |77884 |
# |addr:street                                  |78700 |
# |amenity                                      |85595 |
# |source                                       |99021 |
# |name                                         |142875|
# |power                                        |192944|
# +---------------------------------------------+------+
